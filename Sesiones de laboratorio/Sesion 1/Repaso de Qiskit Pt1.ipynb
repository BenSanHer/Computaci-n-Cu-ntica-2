# %% [markdown]
# #Sesión 1 Laboratorio de Computación Cuántica 2
#
# ##Repaso de Qiskit
#
# En la sesión de hoy nos concentraremos en dar un repaso de los conceptos básicos de Qiskit, con la intención de estar preparados para las próximas sesiones y programar las cosas.
#
# Todo el contenido se manejara principalmente en Colab, sin embargo, si deseas correrlo localmente en tu computadora, puedes instalar Anaconda Navigator y Visual Studio Code para poder correr los programas. En la clase mostraré como hacerlo para que se sientan cómodos, pero no es obligatorio para este curso

# %% [markdown]
# ##¿Qué es Qiskit?
# Qiskit es un framework de software open-source para el desarrollo de algoritmos de computación cuántica. Proporciona herramientas para construir, manipular y ejecutar circuitos cuánticos, así como para simularlos clásicamente o ejecutarlos en hardware cuántico real a través de servicios en la nube.
#
# En esta sesión voy a dar las herramientas básicas para manipular Qiskit. Probablemente los chicos que ya hayan llevado Computación Cuántica 1 ya esten familiariazdos con todo lo que se va a mostrar aquí, sin embargo, buscamos que todos esten en la misma página y podamos avanzar con el resto del contenido del curso

# %%
#Para instalar Qiskit en tu entorno de Colab, puedes correr estas celdas
# !pip install qiskit
# !pip install pylatexenc
# !pip install qiskit-aer
# Out:
# Requirement already satisfied: qiskit in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (1.15.3)
# Requirement already satisfied: dill>=0.3 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: pylatexenc in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (2.10)
# Requirement already satisfied: qiskit-aer in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-aer) (2.3.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-aer) (2.2.6)
# Requirement already satisfied: scipy>=1.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-aer) (1.15.3)
# Requirement already satisfied: psutil>=5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)

# %% [markdown]
# ##Primeros Pasos: Crear un circuito cuántico
#
# Un Qubit es una entidad matemática de la forma  $|\psi\rangle = \alpha|e_0\rangle+\beta|e_1\rangle$, con $|\alpha|^2+|\beta|^2=1.$ donde $|e_i⟩$ es un elemento de una base del espacio $C^2$
#
# $\bullet$ Compuertas. Nos permiten evolucionar el sistema. Estan compuestos de operadores unitarios (Operadores cuyo adjunto hermitiano es su inverso). Los principales son:
#
# >$\star$ Hadamard: $\quad\hat H=\tfrac{1}{\sqrt{2}}\big(|0\rangle\langle0|+|0\rangle\langle1|+|1 \rangle\langle0|-|1\rangle\langle1|\big)$.
#
# >$\star$ Pauli-$z$: $\quad\hat z = |0\rangle\langle0|-|1\rangle\langle1|$
#
# >$\star$ Pauli-$x$: $\quad\hat x = |0\rangle\langle1|+|1\rangle\langle0|$
#
# >$\star$ Pauli-$y$: $\quad\hat y = -i|0\rangle\langle1|+i|1\rangle\langle0|$
#
# >$\star$ Control-NOT: $\quad\mathrm{CNOT}
# \;=\;
# |0\rangle\langle 0| \otimes I
# \;+\;
# |1\rangle\langle 1| \otimes X$
#
#
#
# Vamos a fabricar un circuito en donde apliquemos estos operadores a un sistema cuántico y vamos a visualizarlo. Qiskit SIEMPRE inicia el circuito con los qubits en estado $|0\rangle$

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit

# Crear registros
qr = QuantumRegister(2, name='q')
cr = ClassicalRegister(2, name='c')

# Crear circuito cuántico
qc = QuantumCircuit(qr, cr)

# Aplicar compuertas de un solo qubit

qc.h(qr[0])


# Medición
qc.measure(qr, cr)


# Mostrar el circuito
qc.draw('mpl') #Esto permite realizar el dibujado utilizando MatPlotLib

# %% [markdown]
# Este es un ejemplo de un circuito que corre en 2 Qubits sobre el cual aplicamos el sistema. Es importante notar, que Qiskit invierte la notación de la que estamos acostumbrados a estudiar en el curso. Para qiskit, el qubit 0 es el último qubit en representarse, mientras que los qubit 1, 2, etc, son los primeros en representarse

# %% [markdown]
# Para poder trabajar con los circuitos que ya previamente habiamos realizado, debemos utilizar un Backend, el cual es un programa que permite correr las simulaciones para así poder visualizar como se ve la distribución de probabilidades de nuestro circuito cuántico.
#
# Qiskit Aer es el módulo de Qiskit encargado de la simulación clásica de circuitos cuánticos.
# Su función es permitirnos ejecutar un circuito cuántico en una computadora clásica, sin necesidad de hardware cuántico real.

# %%
from qiskit_aer import AerSimulator

# 1. Creamos un simulador cuántico
#    Usamos el método 'statevector', que internamente calcula el estado cuántico
backend = AerSimulator(method='statevector')

# 2. Ejecutamos el circuito cuántico
#    shots indica cuántas veces repetimos el experimento
job = backend.run(qc, shots=100)

# 3. Obtenemos los resultados de la simulación
resultados = job.result()

# 4. Extraemos los conteos de medición
counts = resultados.get_counts()

# Mostramos los resultados
counts
# Out:
# {'00': 49, '01': 51}

# %% [markdown]
# Igual podemos visualizarlos en un histograma con Qiskit.Visualization

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# A partir de ahora, con las bases claras, vamos a trabajar en Códigos donde aplicaremos lo que ya sabemos desde 0 con la intención de aprender a manejar Qiskit con soltura
#
# Aquí, QuantumCircuit nos hace la Chamba de QuantumRegister y ClassicalRegister en 1

# %%
from qiskit import QuantumCircuit

# 1. Creamos un circuito cuántico con 1 qubit
#    No definimos registros clásicos explícitamente
circuito_hadamard = QuantumCircuit(1)

# 2. Aplicamos la compuerta Hadamard al qubit 0
#    Esto crea una superposición cuántica
circuito_hadamard.h(0)
circuito_hadamard.z(0)
circuito_hadamard.h(0)

# 3. Medimos todos los qubits del circuito
#    Qiskit crea automáticamente un registro clásico
circuito_hadamard.measure_all()

# 4. Dibujamos el circuito
circuito_hadamard.draw('mpl')

# %% [markdown]
# Viendo el circuito ¿Que estado se fabricó y que esperas medir con la simulación? Usaremos el mismo backend que usamos anteriormente

# %%
job = backend.run(circuito_hadamard,shots=1000)

resultados = job.result()
counts = resultados.get_counts()
plot_histogram(counts)

# %% [markdown]
# Ejercicio 1: Cambia UNA SOLA LETRA del código anterior para que la medición siempre mida 1
#
# Ejercicio 2: Si aplicas una compuerta Z en lugar de una Hadamard, ¿Habria algun cambio en la simulación? ¿Por que?
#
# Ejercicio 3: Aplica una compuerta Z sobre el Qubit despues de la compuerta Hadamard y finaliza aplicando una ultima compuerta Hadamard. ¿Cual es tu predicción de lo que vas a medir? ¿Esta predicción fue acertada?
#
# $H|0⟩=\frac{1}{\sqrt{2}}(|0⟩+|1⟩)=|+⟩$
#
#
# $\hat{Z}H|0⟩=\frac{1}{\sqrt{2}}(|0⟩-|1⟩)=|-⟩$
#
# $\hat{H}\hat{Z}H|0⟩=|1⟩$

# %% [markdown]
# Ahora, vamos a fabricar Estados de Bell. ¿Recuerdas cuales son?
#
# $|\Phi^{+}\rangle = \frac{1}{\sqrt{2}}\left(|00\rangle + |11\rangle\right)$
#
#
# $|\Phi^{-}\rangle = \frac{1}{\sqrt{2}}\left(|00\rangle - |11\rangle\right)$
#
#
# $|\Psi^{+}\rangle = \frac{1}{\sqrt{2}}\left(|01\rangle + |10\rangle\right)$
#
# $|\Psi^{-}\rangle = \frac{1}{\sqrt{2}}\left(|01\rangle - |10\rangle\right)$
#
# Te dare el circuito para los estados $|\Phi^{+}\rangle$ y $|\Psi^{+}\rangle$. Tu tendras que fabricar los estados negativos en Qiskit

# %%
from qiskit.quantum_info import Statevector

phimas=QuantumCircuit(2)
phimas.h(0)
phimas.cx(0,1)
phimas.draw('mpl')

# %%
state = Statevector.from_instruction(phimas)

# Mostramos el statevector
state
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
psimas=QuantumCircuit(2)
psimas.h(0)
psimas.cx(0,1)
psimas.x(1)
psimas.draw('mpl')

# %%
state = Statevector.from_instruction(psimas)

# Mostramos el statevector
state
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %% [markdown]
# Ahora, trabajemos con compuerta SWAP:

# %%
# Circuito con 2 qubits
swap_circuit = QuantumCircuit(4)

# Preparamos un estado distinguible
swap_circuit.x(0)        # Estado inicial |01⟩
swap_circuit.h(2)

# Aplicamos SWAP
swap_circuit.swap(0, 1)
swap_circuit.swap(2,3)

# Medimos ambos qubits
swap_circuit.measure_all()

# Dibujamos el circuito
swap_circuit.draw('mpl')

# %%
job = backend.run(swap_circuit, shots=10000)
result = job.result()

counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# Ejercicio: Intenta aplicar una compuerta hadamard en uno de los qubits y visualiza como cambia el aplicar el SWAP a los 2 qubits

# %% [markdown]
# ¿]Y si generalizamos el estado de bell, pero para 3 Qubits?

# %%
# Circuito de 3 qubits
ghz = QuantumCircuit(3)

# 1. Creamos superposición en el qubit 0
ghz.h(0)

# 2. Propagamos la correlación
ghz.cx(0, 1)
ghz.cx(0, 2)

# 3. Medimos todos los qubits
ghz.measure_all()

ghz.draw('mpl')

# %%
job = backend.run(ghz, shots=1000)
result = job.result()

counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# Para terminar, vamos a ver los distintos tipos de compuertas que se pueden aplicar

# %% [markdown]
# $S =
# \begin{pmatrix}
# 1 & 0 \\
# 0 & i
# \end{pmatrix}
# $
#
# $T =
# \begin{pmatrix}
# 1 & 0 \\
# 0 & e^{i\pi/4}
# \end{pmatrix}
# $
#
# $R_x(\theta) =
# \begin{pmatrix}
# \cos\frac{\theta}{2} & -i\sin\frac{\theta}{2} \\
# -i\sin\frac{\theta}{2} & \cos\frac{\theta}{2}
# \end{pmatrix}
# $
#
# $R_y(\theta) =
# \begin{pmatrix}
# \cos\frac{\theta}{2} & -\sin\frac{\theta}{2} \\
# \sin\frac{\theta}{2} & \cos\frac{\theta}{2}
# \end{pmatrix}
# $
#
# $R_z(\theta) =
# \begin{pmatrix}
# e^{-i\theta/2} & 0 \\
# 0 & e^{i\theta/2}
# \end{pmatrix}
# $

# %%
import numpy as np

qc = QuantumCircuit(1)

qc.x(0)
qc.y(0)
qc.z(0)
qc.h(0)
qc.s(0)
qc.t(0)

qc.rx(np.pi/4, 0)
qc.ry(np.pi/4, 0)
qc.rz(np.pi/4, 0)


qc.measure_all()
qc.draw('mpl')

# %%
qc2 = QuantumCircuit(2)

qc2.cx(0, 1)
qc2.cz(0, 1)
qc2.swap(0, 1)

qc2.measure_all()
qc2.draw('mpl')

# %%
qc3 = QuantumCircuit(3)

qc3.ccx(0, 1, 2) #Toffoli

qc3.measure_all()
qc3.draw('mpl')

# %% [markdown]
# Tarea: 1
#
# 1: Fabricar el circuito cuántico para $|\Phi^{-}\rangle$ y $|\Psi^{-}\rangle$ y recuperar tanto las mediciones como el statevector
#
# 2: Investigar que es una fase global en un sistema cuántico y explicarmelo con tus propias palabres y que ademas lo expliquen con un ejemeplo
#
# 3: Fabriquen un circuito usando por lo menos un sistema de 3 qubits y 5 compuertas, desarrollen matemáticamente el circuito para predecir que es lo que esperarían en las mediciones y corran las mediciones en qiskit. Recuerden que Qiskit invierte el orden del sistema

# %%
# !pip install qiskit qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (2.3.0)
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (0.45.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (1.15.3)
# Requirement already satisfied: dill>=0.3 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: requests!=2.32.2,>=2.19 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (2.32.5)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (0.73.2)
# Requirement already satisfied: pydantic>=2.5.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (2.12.5)
# Requirement already satisfied: packaging in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from requests!=2.32.2,>=2.19->qiskit-ibm-runtime) (2026.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.4)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in c:\users\the_b\miniconda3\envs\qiskit-env\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    token="ILqDBElEE_JqB4nnGpK_7WYgdPQ9oEfzpYuBPXqZd70_",
    set_as_default=True,
    overwrite=True,
)

# %%
from qiskit import QuantumCircuit
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

# 1) Cargar credenciales guardadas
service = QiskitRuntimeService()

# 2) Elegir un backend REAL (no simulador), típicamente el menos ocupado
backend = service.least_busy(simulator=False)

# 3) Circuito
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

# 4) Transpilar para ese backend
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(qc)

# 5) Enviar job con primitive Sampler
sampler = Sampler(backend=backend)
job = sampler.run([isa_circuit], shots=1024)

result = job.result()
print(result)
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-02-24 13:02:15,072: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-02-24 13:02:15,812: Loading instance: open-instance, plan: open
# qiskit_runtime_service.backends:WARNING:2026-02-24 13:02:17,364: Using instance: open-instance, plan: open
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 22
#      19 isa_circuit = pm.run(qc)
#      21 # 5) Enviar job con primitive Sampler
# ---> 22 sampler = Sampler(backend=backend)
#      23 job = sampler.run([isa_circuit], shots=1024)
#      25 result = job.result()
#
# TypeError: SamplerV2.__init__() got an unexpected keyword argument 'backend'
